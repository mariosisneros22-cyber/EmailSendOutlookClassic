# %%
import PyPDF2

# %%
with open('FORMATO1.pdf','rb') as pdf_file:
  reader = PyPDF2.PdfReader(pdf_file)
  
  total_pages = len(reader.pages)
  print(f"Total pages: {total_pages}")
  
  first_page = reader.pages[0]
  text = first_page.extract_text()
  print(text)
# Out:
# Total pages: 1
# 2026/03/04 13:18:16 C & M VALCER SAC
# Su operación ha sido realizada
# Número de Operación 000008445
# Tipo de Operación TRANSF A CTAS DE TERCEROS
# Número de Cuenta de Cargo 00110436370100013569
# Titular de la Cuenta Cargo CONSORCIO VALCER UCHUMARCA
# Importe Cargado 104,800.18    SOLES
# Cuenta / Tarjeta / Servicio Beneficiario 00110377960100029090    INSUR SA COMPA#IA DE SEGUROS
# Fecha / Hora 2026-03-04     12:34:47
# Tipo de cambio 0.0000
# Número de Contrato 0
# Referencia 004-OS-01-01-2026 INSURConsulta de Operaciones

# %%
with open('FORMATO2.pdf','rb') as pdf_file:
  reader = PyPDF2.PdfReader(pdf_file)
  
  total_pages = len(reader.pages)
  print(f"Total pages: {total_pages}")
  
  first_page = reader.pages[0]
  text = first_page.extract_text()
  print(text)
# Out:
# Total pages: 3
# 2026/03/04 13:20:41 C & M VALCER SAC
# Consulta de la Orden - Antes del proceso
# Nro. Orden Planilla DescripciónEnviada
# Cuenta de Cargo
# Fecha Hora
# 0304005 PAGO DE PROVEEDORES OFICINA CENTRAL 04/03/2026 12:34:59 0011-0436-0100013569
# Abonos Enviados Moneda de Cargo Importe Inicialmente informado Horario de Ejecución Situación de Proceso
# 1 SOLES 6,614.92 INMEDIATA ABONOS OK
# Consulta de la Orden - Después del proceso
# No. Movimiento de Cargo 000000000
# Fecha y Hora de Ejecución 04/03/2026 - 12:34:59
# Abonos procesados 1
# Importe cargado por abonos 6,614.92 - SOLES
# Abonos NO procesados 0
# Importe NO abonado 0.00 - SOLES
# Comisión por Otra Plaza 0.00 - SOLES
# Comisión Interbancaria 2.50 - SOLES
# TOTAL CARGADO 6,617.42 - SOLES
#   Ver contenido de la planilla
# Relación de las cuentas de abono
# SelNo. Cuenta Banco Titular Doc.Identidad Importe Celular Correo Cant. Doc. SituaciónConsulta de Pagos Masivos
